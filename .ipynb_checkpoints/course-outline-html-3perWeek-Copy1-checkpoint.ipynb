# %% [markdown]
# # Typical Course Schedule (3 meetings/week)

# %% [markdown]
# - 3 lecture meetings/week (42 meetings)
# - 3 lab meetings/week (42 meetings)
# - Meetings 2 through 23 (week 1 through 8) are programming focused.
# - Meetings 24 through 38 can be more data science focused to leverage programming skills
# - Last three meetings are assigned non-assessed if using 3-exam model with a project; use last 3 meetings for project workshops/presentations
# - By end of meeting 12 would have enough material to build a prediction engine to compute roots of numbers using a reduced instruction set (multiply, divide, add, subtract, compare, iterate) limitation as a computational thinking exercise
# - By end of meeting 23 would have enough material to visually fit data models (curves) to observations (markers);

# %% [markdown]
# ---
#
# <strong>Week 1</strong>
#
# 0. introduction
# - syllabus
# - computational thinking concepts
# - jupyterlab/computing environment
#
# 1. problem solving
# - a 6-step protocol
# - decomposition
# - example
#
# 2. expressions
# - fundamental operators
# - arithmetic expressions
# - simple output: print()
#
# ---
#
# <strong>Week 2</strong>
#
# 3. data types; typecasting
# - integer
# - float
# - string
#
# 4. variables
# - what are variables?
# - naming conventions
# - the assignment symbol
#
#
# 5. mutable data structures
# - lists
# - dictionaries
# - name;position/key;value
#
# ---
#
# <strong>Week 3</strong>
#
# 6. immutable data structures
# - tuple
# - name;position;value
# - subtopic
#
# 7. user interaction
# - input()
# - triple quotes
# - escape characters
#
# 8. algorithm building blocks
# - sequence
# - selection
# - repetition
#
# ---
#
# <strong>Week 4</strong>
#
# 9. sequential structure
# - notebook computation flow
# - sequential arithmetic
# - reset the notebook
#
# 10. selection structure
# - Inline IF
# - IF ... ELSE block
# - nested if structures
#
# 11. count controlled repetition
# - FOR structures
# - loop traverse controls(break,pass,continue)
# - nested loop structures
#
# <font color="red"><strong> Exam 1 </strong></font>
#
# ---
#
# <strong>Week 5</strong>
#
# 12. sentinel controlled repetition
# - WHILE structures
# - loop traverse controls(break,pass,continue)
# - nested loop structures
#
# 13. <font color="red"><strong> a computational thinking challenge </strong></font>
# - finding roots without exponentiation using core python
# - allow multiply,divide,add,subtract,compare,repetition
# - finds square root of a number using only a reduced instruction set
#
# 14. functions
# - what are functions?
# - intrinsic and core externals (e.g. math)
# - variable scope
#
# ---
#
# <strong>Week 6</strong>
#
# 15. external modules
# - defining your own functions
# - importing modules
# - creating your own modules
#
# 16. working with files
# - opening and reading text (ascii) files
# - using FOR loop to read a text file
# - writing to a text file
#
# 17. more file manipulation
# - open/read/write binary files
# - deleting and renaming files
# - get a file from a URL
#
# ---
#
# <strong>Week 7</strong>
#
# 18. working with array
# - vectors and matrices
# - array a special type of list
# - matrix arithmetic
#
# 19. array processing with numpy
# - linear algebra using using numpy
# - solve linear system in numpy
# - example
#
# 20. database concepts
# - records,fields
# - unique identifiers/keys
# - create, read, update, delete
#
# ---
#
# <strong>Week 8</strong>
#
# 21. database processing with pandas
# - subtopic
# - subtopic
# - subtopic
#
# 22. visual display of data
# - plot types
# - plot uses
# - plot conventions
#
# 23. plotting with matplotlib
# - line plots
# - scatter plots
# - decorators
#
# <font color="red"><strong> Exam 2 </strong></font>
#
# ---
#
# <strong>Week 9</strong>
#
# 24. data models and visualization
# - interpolation using lagrange polynomials
# - fitting an arbitrary function (trial-and-error)
# - fitting a polynomial (linear system)
#
# 25. data models and statistics
# - causality
# - randomness
# - finding probabilities
#
# 26. sampling and distributions
# - populations and distributions
# - sampling with/without replacement
# - sample distributions
#
# <strong><font color="red"> Introduce Semester Project </font></strong>
#
#
# ---
#
# <strong>Week 10</strong>
#
# 27. describing samples and populations
# - measures of central tendency (mean,median,mode)
# - measures of dispersion (variance, std. deviation)
# - measures of symmetry (skewness)
#
# 28. comparing samples
# - proportions and hypothesis tests
# - error types
# - attained significance
#
# 29. interval estimates
# - concept of a confidence interval
# - bootstrapping/simulation to generate interval samples
# - parameter interval estimates as a type of hypothesis test
#
# ---
#
# <strong>Week 11</strong>
#
# 30. prediction models and regression
# - data modeling via curve fitting
# - concept of squared error
# - mathematics of minimizing the error
#
# 31. ordinary least squares
# - explainatory (predictor) features
# - response (prediction) features
# - residuals
#
# 32. estimation by least squares
# - parameter intervals
# - prediction intervals
# - inference
#
# ---
#
# <strong>Week 12</strong>
#
# 33. alternate models
# - exponential and logarithmic models
# - power-law models
# - polynomial models
#
# 34. logistic regression
# - logit model
# - binary classifications
# - examples
#
# 35. title
# - subtopic
# - subtopic
# - subtopic
#
# ---
#
# <strong>Week 13</strong>
#
#
# 36. distribution model functions
# - normal/log-normal
# - gamma/weibull
# - gumbell(double exponential)
#
# 37. probability estimation modeling
# - ranking, order
# - plotting position formulas
# - data modeling via distribution fitting
#
# 38. distribution model estimates
# - fitting by visualization (trial-and-error)
# - method of moments
# - maximum likelihood method
#
# <font color="red"><strong> Exam 3 </strong></font>
#
# ---
#
# <strong>Week 14</strong>
#
# 39. title (not assessed - use for project presentations)
# - subtopic
# - subtopic
# - subtopic
#
# 40. title (not assessed - use for project presentations)
# - subtopic
# - subtopic
# - subtopic
#
# 41. title (not assessed - use for project presentations)
# - subtopic
# - subtopic
# - subtopic
