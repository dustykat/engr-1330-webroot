# %%
# Preamble script block to identify host, user, and kernel
import sys
! hostname
! whoami
print(sys.executable)
print(sys.version)
print(sys.version_info)
# Out:
# atomickitty.aws
# compthink
# /opt/conda/envs/python/bin/python
# 3.8.3 (default, Jul  2 2020, 16:21:59)
# [GCC 7.3.0]
# sys.version_info(major=3, minor=8, micro=3, releaselevel='final', serial=0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
#
# The table below contains experimental observations.

# %% [markdown]
# |Elapsed Time (s)|Speed (m/s)|
# |---:|---:|
# |0 |0|
# |1.01 |3|
# |2.07 |7|
# |3.3 |12|
# |4.2 |20|
# |5.3 |30|
# |6.1 | 45.6|
#
# Plot the speed vs time (speed on y-axis, time on x-axis) using a line plot.
# From examination of  the plot, estimate the speed at time t = 5.0 (eyeball estimate)

# %%
# Create two lists; time  and speed
time = [0,1.01,2.07,3.3,4.2,5.3,6.1]
speed = [0,3,7,12,20,30,45.6]

# %%
# Create a line chart of speed on y axis and time on x axis
mydata = plt.figure(figsize = (10,5)) # build a square drawing canvass from figure class
plt.plot(time, speed, c='red', marker='v',linewidth=1) # basic line plot
plt.show()

# %% [markdown]
# ## Exercise 2
# Using the same series from Exercise 1, Plot the speed vs time (speed on y-axis, time on x-axis) using a scatter plot.
# From examination of  the plot, estimate the speed at time t = 2.0 (eyeball estimate)

# %%
# Create a markers only line chart
mydata = plt.figure(figsize = (10,5)) # build a square drawing canvass from figure class
plt.scatter(time, speed, c='red', marker='^') # basic scatter plot
plt.show()

# %% [markdown]
# ## Exercise 3
# Using the same series from Exercise 1, Plot the speed vs time (speed on y-axis, time on x-axis) using a line plot. Plot a second line based on the linear model
#
# $$y = mx + b$$,
#
# where $$b=0~\text{and}~m=7.6$$.

# %%
# Code and run your solution here:
def ymodel(xmodel,slope,intercept):
    ymodel = slope*xmodel+intercept
    return(ymodel)

yseries = []
slope = 7.6
intercept = 0.0

for i in range(0,len(time)):
    yseries.append(ymodel(time[i],slope,intercept))
# Create a markers only line chart
mydata = plt.figure(figsize = (10,5)) # build a square drawing canvass from figure class
plt.plot(time, speed, c='red', marker='^',linewidth=0) # basic scatter plot
plt.plot(time, yseries, c='blue') 
plt.show()

# %% [markdown]
# ## Exercise 4
# Using trial and error try to improve the 'fit' of the model, by adjusting values of $$m~\text{and}~b$$.

# %%
# Code and run your solution here:
yseries = []
slope = 7.6
intercept = -8.0

for i in range(0,len(time)):
    yseries.append(ymodel(time[i],slope,intercept))
# Create a markers only line chart
mydata = plt.figure(figsize = (10,5)) # build a square drawing canvass from figure class
plt.plot(time, speed, c='red', marker='^',linewidth=0) # basic scatter plot
plt.plot(time, yseries, c='blue') 
plt.show()

# %%
# Change time 3 to 2.3 and repeat both plots
time[3]=2.3

# %% [markdown]
# ## Exercise 5
# Use pandas to read a dataframe from the file `census_18.csv`.  Then produce a line plot of
# the counts by age for the 2010 census, x-axis will be the series `age`, y-axis will be the census values for `2010`.

# %%
df = pd.read_csv('census_18.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-1da8cd2be0d1> in <module>
# ----> 1 df = pd.read_csv('census_18.csv')
#       2 df.head()
#
# /opt/conda/envs/python/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /opt/conda/envs/python/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /opt/conda/envs/python/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /opt/conda/envs/python/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /opt/conda/envs/python/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File census_18.csv does not exist: 'census_18.csv'

# %%
! ls -la
# Out:
# total 320
# drwxr-xr-x 3 compthink compthink   4096 Sep 22 00:08 .
# drwxrwxr-x 6 compthink compthink   4096 Sep 22 00:08 ..
# drwxrwxr-x 2 compthink compthink   4096 Sep 22 00:08 .ipynb_checkpoints
# -rw-rw-r-- 1 compthink compthink 245693 Sep 22 00:06 Lesson9-AsANotebook.ipynb
# -rw-rw-r-- 1 compthink compthink  62329 Sep 21 22:36 SearchPyplot.png
# -rw-rw-r-- 1 compthink compthink   2703 Aug 20 19:54 galton_subset.csv
