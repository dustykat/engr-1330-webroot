# %% [raw]
# import indeterminatebeam
# import matplotlib
# matplotlib.pyplot.ion()
# %matplotlib inline

# %%
import beambending
import matplotlib
matplotlib.pyplot.ion()

# %%
beam = beambending.Beam(9)
beam.pinned_support = 2
beam.rolling_support = 7
beam.add_loads((
                beambending.PointLoadH( 10, 5.0),
                beambending.PointLoadV(-45, 4.0),
                beambending.PointLoadV(-45, 5.0),
                #beambending.DistributedLoadV(-10, (0, 9)),
                #beambending.DistributedLoadV(-20 + x**2, (0, 2)),
))
fig = beam.plot()
