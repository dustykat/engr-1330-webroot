# %% [markdown]
# # <font color=darkblue>Week 3 Assignment </font>

# %% [markdown]
# ## Full name:
# ## R#:
# ## Title of the notebook:
# ## Date:

# %% [markdown]
# #### Question 0: Write a for loop to get the sum all even numbers from 1 to n, where n is given by user via the input( ) function

# %% [markdown]
# **(20 points)**

# %% [markdown]
# #### Question 1: Write a for loop to find those numbers which are divisible by 7 and divisible by 5, between 1500 and 2700 (both included).

# %% [markdown]
# **(20 points)**

# %% [markdown]
# #### Question 2: Choose and initialize three floating-point numbers and then, write a function to find the maximum value among those three numbers.
#
# **Note-1: Initialize three floating-point numbers to three different variable names of your choice. Then, pass those three variable names to a function that you write.  Inside the function, start by first assuming that one of the three numbers is maximum (i.e., give a new variable name to one of the three numbers assuming that it is the maximum value) and then, write two if conditional statements to check whether the number that you have assumed to be maximum is less than than the other two numbers.  Specifically, if the number that you chose to be maximum in the initial step is less than the number that you check against (i.e., one of the other two numbers) in the first if conditional statement, replace that number to be the maximum value and use that in the second if conditional statement to check against the another number and repeat the same process that you did in the first if conditional statement. After checking using the conditional statements correctly, return the maximum value among those three numbers.**
#
# **Note-2: See below for a visual representation of the algorithm (involving an example of three numbers) that you must write.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **(10 points)**

# %% [markdown]
# #### Question 3: Choose and initialize three floating-point numbers and then, write a function to find the maximum value among those three numbers.
#
# **Note: Initialize a list that contains three floating-point numbers of your choice. Then, pass that list as an argument to the function that you write and use max() function inside your function to get the maximum value in that list.**

# %% [markdown]
# **(20 points)**

# %% [markdown]
# #### Question 4:  Choose and initialize the x-coordinate and the y-coordinate for two different points and then, write a function to calculate the Euclidean distance between those two points.
#
# **Note: Initialize two lists. One list must contain the x- and the y-coordinate of one point (i.e., [x1, y1]) and the other list must contain the x- and the y-coordinate of other point (i.e., [x2, y2]). Once you do that correctly, pass those lists as arguments to the functions.**
#
# **Hint: Use the idea of indexing the lists to implement the formula to calculate the Euclidean distance that is shown below inside the function that you write.**
#
# $$Distance = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}$$

# %% [markdown]
# ![distance_between_points_image.jpg](https://www.mathematics-monster.com/images3/distance_between_points_image.jpg)

# %% [markdown]
# **(20 points)**

# %% [markdown]
# #### Question 5: Assume that the time taken to travel from location A to location B is x hours, y minutes, and z seconds.  Initialize the hours, minutes, and seconds using the input( ) function and choose your own values for hours, minutes, and seconds.  Then, write a function to convert hours, minutes, and seconds into total seconds that takes to travel from location A to location B.
#
# **Conversion:**
#
# $$1\,hour = 3600\,seconds$$
# $$1\,minute = 60\,seconds$$

# %% [markdown]
# **(10 points)**
