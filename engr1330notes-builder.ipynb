# %%
import sys
! pwd
# Out:
# /home/sensei/ce-5333-sensors-webroot/p4ebyexample

# %% [raw]
# ! jupyter-book clean engr1330notes/

# %%
! jupyter-book build engr1330notes
# Out:
# Running Jupyter-Book v0.12.0
# Source Folder: /home/sensei/engr-1330-webroot/engr1330notes
# Config Path: /home/sensei/engr-1330-webroot/engr1330notes/_config.yml
# Output Path: /home/sensei/engr-1330-webroot/engr1330notes/_build/html
# Running Sphinx v3.5.2
# [etoc] Changing master_doc to 'intro'
# loading pickled environment... failed
# failed: source directory has changed
# checking for /home/sensei/engr-1330-webroot/engr1330notes/references.bib in bibtex cache... not found
# parsing bibtex file /home/sensei/engr-1330-webroot/engr1330notes/references.bib... parsed 5 entries
# ...

# %% [markdown]
# #
